# %% [markdown]
# # 结构探针实验
#
# 验证「高低点/走势结构」特征对 BTC 未来 60/300/900 分钟方向是否有可预测性。
# CPU 即可，需开 Internet(拉 OKX 数据 + clone GitHub)。判读标准见脚本尾部输出。

# %%
import os
if not os.path.exists('kline-de-pre-model'):
    # !git clone --depth 1 https://github.com/lin7c/kline-de-pre-model.git
# %cd kline-de-pre-model
# !pip -q install 'requests>=2.32' 'pandas>=2.2' 'scikit-learn>=1.5'

# %%
# !python probe_structure.py 300000
